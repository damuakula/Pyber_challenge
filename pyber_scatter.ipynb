# %%
# %matplotlib inline

# Setup Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Setup City and Ride data from csv files
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data from csv files
ride_data = pd.read_csv(ride_data_to_load)
city_data =  pd.read_csv(city_data_to_load)

# Combine the City and Ride data into a single dataset
pyber_df = pd.merge(ride_data, city_data, how='left', on='city')

# Display the combined data table for preview
pyber_df
# Out:
#                      city                 date   fare        ride_id  \
# 0      Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1      South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2      Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3              Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4              South Jack  2018-03-06 04:28:35  34.58  3908451377344
# 5            South Latoya  2018-03-11 12:26:48   9.52  1994999424437
# 6           New Paulville  2018-02-27 11:17:56  43.25   793208410091
# 7            Simpsonburgh  2018-04-26 00:43:24  35.98   111953927754
# 8         South Karenland  2018-01-08 03:28:48  35.09  7995623208694
# 9           North Jasmine  2018-03-09 06:26:29  42.81  5327642267789
# 10    New Kimberlyborough  2018-02-07 01:10:11   9.34  7992781920789
# 11            West Angela  2018-01-12 01:45:27  26.86  4820052223501
# 12             Rodneyfort  2018-03-02 18:03:20  44.26  2494064867705
# 13            West Angela  2018-01-10 12:17:31  12.74  2108723916092
# 14            Roberthaven  2018-05-04 14:48:56  25.66  1026197778354
# 15            North Jason  2018-03-28 22:28:44   9.19  7007022521141
# 16           Williamsview  2018-01-03 16:19:25  18.93  1979492913169
# 17                Leahton  2018-02-26 18:42:15   8.85  6966668662612
# 18           West Anthony  2018-03-06 02:27:01  10.02  9396763280782
# 19    New Kimberlyborough  2018-04-25 22:58:38  29.67  4823568522144
# 20            Roberthaven  2018-02-24 10:26:34   7.80  2180566685151
# 21            New Paulton  2018-05-01 03:12:49   8.28  8527101897862
# 22    West Patrickchester  2018-03-19 05:46:20  40.86   898889456779
# 23              Deanville  2018-04-25 03:29:09  41.52  6055928921559
# 24        West Josephberg  2018-02-19 16:22:09  36.39  3322126516683
# 25       West Samuelburgh  2018-05-03 14:33:41  41.12  7330842806458
# 26             West Heidi  2018-03-14 23:46:50  24.40  4908573010166
# 27              Loganberg  2018-04-01 01:06:03   8.23   678728883160
# 28            Huntermouth  2018-02-10 23:32:13  25.79  1880379662035
# 29           South Latoya  2018-01-11 18:44:14  27.41  8662301917375
# ...                   ...                  ...    ...            ...
# 2345         West Heather  2018-02-04 16:29:23  13.97  7118893881453
# 2346         West Heather  2018-04-18 19:33:12  46.60  3671003215967
# 2347         West Heather  2018-03-02 21:04:10  20.99  5766454453070
# 2348      South Saramouth  2018-01-28 15:55:33  31.25  7118046558393
# 2349         West Heather  2018-03-06 20:06:51  48.11  2570548892682
# 2350            Garzaport  2018-05-06 16:57:16  18.90  8826696981094
#
# [2375 rows x 6 columns]

# %%
group_city_df = pyber_df.groupby(['city'])
group_city_df

# %%
group_type_df = pyber_df.groupby(['type'])
group_type_df["ride_id"].count()
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
urban_city_df = pyber_df.loc[(pyber_df['type'] == "Urban")]
suburban_city_df = pyber_df.loc[(pyber_df['type'] == "Suburban")]
rural_city_df = pyber_df.loc[(pyber_df['type'] == "Rural")]

# %%
type_fare_group = group_type_df["fare"].sum()
type_fare_group
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
group_driver_df = city_data.groupby(['type'])
type_driver_group = group_driver_df["driver_count"].sum()
type_driver_group
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
total_drivers = city_data["driver_count"].sum()
total_drivers
# Out:
# 2973

# %%
percent_total_fares_urban = round((type_fare_group["Urban"]/(type_fare_group["Urban"] + type_fare_group["Suburban"] + type_fare_group["Rural"]))*100,2)
percent_total_fares_suburban = round((type_fare_group["Suburban"]/(type_fare_group["Urban"] + type_fare_group["Suburban"] + type_fare_group["Rural"]))*100,2)
percent_total_fares_rural = round((type_fare_group["Rural"]/(type_fare_group["Urban"] + type_fare_group["Suburban"] + type_fare_group["Rural"]))*100,2)

# %%
percent_total_rides_urban = round((len(urban_city_df)/(len(urban_city_df) + len(suburban_city_df) + len(rural_city_df)))*100,2)
percent_total_rides_suburban = round((len(suburban_city_df)/(len(urban_city_df) + len(suburban_city_df) + len(rural_city_df)))*100,2)
percent_total_rides_rural = round((len(rural_city_df)/(len(urban_city_df) + len(suburban_city_df) + len(rural_city_df)))*100,2)

# %%
percent_total_drivers_urban = round((type_driver_group["Urban"]/total_drivers)*100,2)
percent_total_drivers_suburban = round((type_driver_group["Suburban"]/total_drivers)*100,2)
percent_total_drivers_rural = round((type_driver_group["Rural"]/total_drivers)*100,2)

# %%
urban_group = urban_city_df.groupby(['city'])
suburban_group = suburban_city_df.groupby(['city'])
rural_group = rural_city_df.groupby(['city'])

# %%
driver_count_urban_city = urban_group["driver_count"].count()
driver_count_suburban_city = suburban_group["driver_count"].count()
driver_count_rural_city = rural_group["driver_count"].count()

# %%
average_urban_fare = urban_group["fare"].mean()
average_suburban_fare = suburban_group["fare"].mean()
average_rural_fare = rural_group["fare"].mean()

# %%
urban_rides_per_city = urban_group["ride_id"].count()
suburban_rides_per_city = suburban_group["ride_id"].count()
rural_rides_per_city = rural_group["ride_id"].count()

# %%
type1 = (urban_rides_per_city,average_urban_fare)
type2 = (suburban_rides_per_city,average_suburban_fare)
type3 = (rural_rides_per_city,average_rural_fare)

data = (type1, type2, type3)
colors = ("tomato", "lightskyblue", "gold")
groups = ("Urban", "Suburban", "Rural")
drivers = (driver_count_urban_city,driver_count_suburban_city,driver_count_rural_city)

for data, color, group, driver in zip(data, colors, groups, drivers):
   x, y = data
   plt.scatter(x, y, alpha=0.8, c=color, edgecolors='black', s=driver*10, label=group)

plt.xlabel('Total Number of Rides (Per City)', fontsize=15)
plt.ylabel('Average Fare($)', fontsize=15)
plt.title('Pyber Ride Sharing Data (2016)',fontsize=18)

plt.grid(True)
plt.legend(loc=1)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Labels for the city types of the pie chart
labels = ["Urban", "Suburban", "Rural"]

# The ride values of each section of the pie chart
ridesizes = [percent_total_rides_urban, percent_total_rides_suburban, percent_total_rides_rural]

# The ride values of each section of the pie chart
faresizes = [percent_total_fares_urban, percent_total_fares_suburban, percent_total_fares_rural]

# The ride values of each section of the pie chart
driversizes = [percent_total_drivers_urban, percent_total_drivers_suburban, percent_total_drivers_rural]

# The colors of each section of the pie chart
colors = ["tomato", "lightskyblue", "gold"]

# Separates the "Urban" section from other types
explode = (0.1, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.title('Total Fares by City Type',fontsize=18)
plt.pie(faresizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c0202ae860>,
#   <matplotlib.patches.Wedge at 0x2c0202b8278>,
#   <matplotlib.patches.Wedge at 0x2c0202b8c18>],
#  [Text(-0.35270227937197973, -1.1469965571551688, 'Urban'),
#   Text(0.5391897459930073, 0.9587879941968384, 'Suburban'),
#   Text(-0.6732991803460204, 0.8698667793089797, 'Rural')],
#  [Text(-0.20574299630032147, -0.6690813250071816, '62.7%'),
#   Text(0.29410349781436756, 0.5229752695619118, '30.5%'),
#   Text(-0.36725409837055656, 0.4744727887139889, '6.8%')])

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.title('Total Rides by City Type',fontsize=18)
plt.pie(ridesizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c0202f57b8>,
#   <matplotlib.patches.Wedge at 0x2c0202fe1d0>,
#   <matplotlib.patches.Wedge at 0x2c0202feb70>],
#  [Text(-0.14299981306895682, -1.191449140107224, 'Urban'),
#   Text(0.308954619978567, 1.0557211008566132, 'Suburban'),
#   Text(-0.7148597742680461, 0.8360475483687746, 'Rural')],
#  [Text(-0.08341655762355812, -0.6950119983958807, '68.4%'),
#   Text(0.16852070180649106, 0.5758478731945162, '26.3%'),
#   Text(-0.38992351323711605, 0.456025935473877, '5.3%')])

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.title('Total Drivers by City Type',fontsize=18)
plt.pie(driversizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c02033d630>,
#   <matplotlib.patches.Wedge at 0x2c020346048>,
#   <matplotlib.patches.Wedge at 0x2c0203469e8>],
#  [Text(0.3230378022870515, -1.155701768750724, 'Urban'),
#   Text(-0.20800658359115742, 1.0801542765654983, 'Suburban'),
#   Text(-0.7816568828107858, 0.7739589895818291, 'Rural')],
#  [Text(0.18843871800078, -0.674159365104589, '80.9%'),
#   Text(-0.11345813650426767, 0.5891750599448172, '16.5%'),
#   Text(-0.426358299714974, 0.4221594488628158, '2.6%')])
